# %% [markdown]
# #Pivot Table & Charts
#
# 1. What is the purpose of a PivotTable in Excel?
#
# - The purpose of an Excel PivotTable is to summarize, analyze, explore, and present large amounts of complex data quickly and interactively, allowing you to transform rows into columns and vice versa to uncover trends, patterns, and insights without complex formulas.
#
# 2. Create a PivotTable to show Total Sales by Region.
#
# -![image.png](data:image/png;base64,...)
#
# 3. Apply Conditional Formatting to highlight sales greater than 400.
#
# - ![image.png](data:image/png;base64,...)
#
# 4. Explain the difference between Sorting and Filtering with an example from this dataset.
#
# - sorted the dataset with products in ascending order.
#   ![image.png](data:image/png;base64,...)
#
#   5. Create a PivotChart showing Monthly Sales Trend.
#
#   - ![image.png](data:image/png;base64,...)
#
#   6. Use a Slicer to filter data by Product and observe changes in sales
#
#   - ![image.png](data:image/png;base64,...)
#
#   7. Why are Dashboards important for decision-making in business analysis?
#
#  - Dashboards are crucial for business analysis and decision-making because they consolidate complex data into clear, real-time visualizations, enabling quick identification of trends, problems, and opportunities, facilitating faster, data-driven choices, improving focus on key performance indicators (KPIs), and allowing for proactive problem-solving and strategic planning
#
#  8. Create a Dashboard that includes:
#
#      .Sales by Region (PivotTable + Chart)
#      .Product Filter (Slicer)
#      .Monthly Trend (Line Chart)
#
# - Sales by Region (PivotTable + Chart)
#   ![image.png](data:image/png;base64,...)
#
#   - Product Filter (Slicer)
#    ![image.png](data:image/png;base64,...)
#
#    - Monthly Trend (Line Chart)
#      ![image.png](data:image/png;base64,...)
#
#   9. Group dates in the PivotTable into Months and calculate the average sales per month.
#
#   - ![image.png](data:image/png;base64,...)
#
#   10. Combine Apples and Oranges into one group called Fruits and compare its sales with other products.
#
#   -![image.png](data:image/png;base64,...)

# %% [markdown]
# #Pivot Table & Charts
#
# 1. What is the purpose of a PivotTable in Excel?
#
# -
